# %% [markdown]
# # Tugas 1 : Data Integration

# %%
import pandas as pd

#MENGGABUNGKAN DATA DENGAN "MERGE"

data_salesM1 = pd.read_csv("D:\DATA MINING\Data_SalesM1.csv")
data_salesM2 = pd.read_csv("D:\DATA MINING\Data_SalesM2.csv")

data_salesM = pd.merge(data_salesM1, data_salesM2, on=["Product_Code"])
data_salesM.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W11  W12  W13  W14  \
# 0           P1  11  12  10   8  13  12  14  21   6 ...    14   16    9    9
# 1           P2   7   6   3   2   7   1   6   3   3 ...     2    6    2    0
# 2           P3   7  11   8   9  10   8   7  13  12 ...     9    4    7   12
# 3           P4  12   8  13   5   9   6   9  13  13 ...     4    5    4   15
# 4           P5   8   5  13  11   6   7   9  14   9 ...    18    8    4   13
#
#    W15  W16  W17  W18  W19  W20
# 0    9   14    9    3   12    5
# 1    6    2    7    7    9    4
# 2    8    7   11   10    7    7
# 3    7   11    9   15    4    6
# 4    8   10   15    6   13   11
#
# [5 rows x 22 columns]

# %%
import pandas as pd

#MENGGABUNGKAN DATA DENGAN "CONCAT"

data_salesC1 = pd.read_csv("D:\DATA MINING\Data_SalesC1.csv")
data_salesC2 = pd.read_csv("D:\DATA MINING\Data_SalesC2.csv")

data_salesC = pd.concat([data_salesC1, data_salesC2])
data_salesC.head()
# Out:
#   Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W10  W11  W12  W13  \
# 0           P1  11  12  10   8  13  12  14  21   6 ...    11   14   16    9
# 1           P2   7   6   3   2   7   1   6   3   3 ...     2    2    6    2
# 2           P3   7  11   8   9  10   8   7  13  12 ...    14    9    4    7
# 3           P4  12   8  13   5   9   6   9  13  13 ...     8    4    5    4
# 4           P5   8   5  13  11   6   7   9  14   9 ...    11   18    8    4
#
#    W14  W15  W16  W17  W18  W19
# 0    9    9   14    9    3   12
# 1    0    6    2    7    7    9
# 2   12    8    7   11   10    7
# 3   15    7   11    9   15    4
# 4   13    8   10   15    6   13
#
# [5 rows x 21 columns]

# %%
data_salesC
# Out:
#    Product_Code  W0  W1  W2  W3  W4  W5  W6  W7  W8 ...   W10  W11  W12  W13  \
# 0            P1  11  12  10   8  13  12  14  21   6 ...    11   14   16    9
# 1            P2   7   6   3   2   7   1   6   3   3 ...     2    2    6    2
# 2            P3   7  11   8   9  10   8   7  13  12 ...    14    9    4    7
# 3            P4  12   8  13   5   9   6   9  13  13 ...     8    4    5    4
# 4            P5   8   5  13  11   6   7   9  14   9 ...    11   18    8    4
# 5            P6   3   3   2   7   6   3   8   6   6 ...     1    1    5    4
# 6            P7   4   8   3   7   8   7   2   3  10 ...     5    2    3    4
# 7            P8   8   6  10   9   6   8   7   5  10 ...     8    8   15    9
# 8            P9  14   9  10   7  11  15  12   7  13 ...    15   15   16   10
# 9           P10  22  19  19  29  20  16  26  20  24 ...    31   22   23   19
# 10          P11  15   7  15  14  17   7  10  16  11 ...     8   10   10   12
# ...

# %%
data_salesM.to_csv("datasales1.csv")
data_salesC.to_csv("datasales2.csv")
